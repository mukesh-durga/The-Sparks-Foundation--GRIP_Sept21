# %% [markdown]
# ![LOGO2-2.png](attachment:LOGO2-2.png)

# %% [markdown]
# <p style="font-size:22px;"><b> PREDICTION USING DECISION TREE ALGORITHM(TASK-3) </b> </p>
#
# --------------
#
# ![Prediction-Task3.png](attachment:Prediction-Task3.png)
#
# <p style="font-size:21px;"> <b> BY: DURGA MUKESH </b> </p>

# %% [markdown]
# # Introduction:
# ## Problem Statement:
# Prediction using Decission Tree Algorithm.
# Creating the Decission Tree classifier and Visualizing it graphically.
# The purpose is if we feed any new data to this classifier, it would be able to predict the right class accordingly.
#
# ## Decission Tree Algorithm:
# * Decision Tree is a Supervised learning technique that can be used for both classification and Regression problems, but mostly it is preferred for solving Classification problems. It is a tree-structured classifier, where internal nodes represent the features of a dataset, branches represent the decision rules and each leaf node represents the outcome.
# * It is a graphical representation for getting all the possible solutions to a problem/decision based on given conditions.
# * In a Decision tree, there are two nodes, which are the Decision Node and Leaf Node. Decision nodes are used to make any decision and have multiple branches, whereas Leaf nodes are the output of those decisions and do not contain any further branches.
# ![Decission%20Tree.png](attachment:Decission%20Tree.png)

# %% [markdown]
# # Importing Necessary Libraries:

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.tree import DecisionTreeRegressor

# %%
df = pd.read_csv("Iris.csv")

# %%
# A glimpse of the Dataset:
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Information and Statistics of the Dataset:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# # Checking for Data Balance:

# %%
df.Species.value_counts()
# Out:
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %% [markdown]
# **As we can observe, the species data are balanced, and there anr no missing values.**

# %% [markdown]
# # Creating Train and Test Data sets:

# %%
X= df.iloc [:,1:-1]
Y= df.iloc[:,-1]
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.1,random_state=0)

# %% [markdown]
# # Data Visualisation:

# %%
df=df.iloc[:,1:]
sns.pairplot(df,hue='Species', palette = "rocket")
plt.show()

# %% [markdown]
# **We can see the difference that one species-IRIS SETOSA has attributes different from the other 2 species-IRIS VERSICOLOR,IRIS VIRGINICA**

# %% [markdown]
# # Decission Tree:

# %%
lm= DecisionTreeClassifier(random_state=0)
lm.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
Y_train_pred=lm.predict(X_train)
Y_test_pred=lm.predict(X_test)
print("Train accuracy score:",accuracy_score(Y_train,Y_train_pred))
print("Test accuracy score:",accuracy_score(Y_test,Y_test_pred))
# Out:
# Train accuracy score: 1.0
# Test accuracy score: 1.0

# %%
plt.figure (figsize=(12,12))
plot_tree(lm,filled= True)
print()

# %% [markdown]
# ***THANK YOU***
